# %%
# Literales que parecen idénticos pero no lo son
print("2")
print(2)
# Out:
# 2
# 2

# %%
# Podemos ver la diferencia con el operador de suma
print("2" + "2")
print(2 + 2)
# Out:
# 22
# 4

# %%
# Los literales enteros son números naturales que no pueden tener parte decimal
print(1232)
# Out:
# 1232

# %%
# Los enteros no se escriben con separadores de miles
print(1,232)
print(1.232)
# Out:
# 1 232
# 1.232

# %%
# Por claridad se permite el guion bajo como separador
# En realidad el separador se descarta
print(1_232)
# Y se puede colocar en cualquier lugar
print(1_2_3_2)
# Out:
# 1232
# 1232

# %%
# También podemos usar el signo "-" para enteros negativos
print(-1232)
# Y el signo "+" opcional para los positivos
print(+1232)
# Out:
# -1232
# 1232

# %%
# Números binarios
print(0b1011)
# Out:
# 11

# %%
# Númmeros octales
print(0o123)
print(0o15 + 0o16)
# Out:
# 83
# 27

# %%
# Números hexadecimales
print(0xff)
# Out:
# 255

# %%
# Números flotantes
print(2.5)
print(.5)
print(4.)
# Out:
# 2.5
# 0.5
# 4.0

# %%
# Números flotantes en notación científica
# la e indica potencia de 10 (base y exponente)
print(3e8)
print(6.62607e-34)
print(12e2)
print(12e-2)
# Out:
# 300000000.0
# 6.62607e-34
# 1200.0
# 0.12

# %%
# Python elige por defecto la notación más corta del número
print(0.0000000000000000000001)
print(2e-5)
# Out:
# 1e-22
# 2e-05

# %%
# Cadenas de caracteres
print("Me gusta \"Monty Python\"")
print('Me gusta "Monty Python"')
# Out:
# Me gusta "Monty Python"
# Me gusta "Monty Python"

# %%
'''
Ejercicio
Intenta imprimir una cadena que contenga el siguiente mensaje:
I'm Monty Python.
a) Representando la cadena con comillas dobles
b) Representando la cadena con comillas simples con \
c) Repite b) Sin usar el caracter de escape \
'''
print("I'm Monty Python.")
print('I\'m Monty Python.')
print('I{comillas}m Monty Python.'.format(comillas="'"))
comilla = "'"
print('I', comilla, 'm Monty Python.',sep='')
print('''I'm Monty Python.
  iui''')
# Out:
# I'm Monty Python.
# I'm Monty Python.
# I'm Monty Python.
# I'm Monty Python.
# I'm Monty Python.
#   iui

# %%
# Booleanos
print(True)
print(False)
# Esto es una cadena, no un booleano
print("True")
# Out:
# True
# False
# True

# %%
# El resultado de un operador de comparación es un booleano
print(1 > 2)
print(1 < 2)
# Out:
# False
# True

# %%
'''
Ejercicio
Intenta averiguar el tipo de los siguientes literales
'''
print(type("Hola"))
print(type("123"))
print(type(123))
print(type(1.5))
print(type(2))
print(type(2.5))
print(type(2.))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
