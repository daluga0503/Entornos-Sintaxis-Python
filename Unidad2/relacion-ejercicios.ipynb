# %%
# Ejercicio 1 1. Realizar un programa que muestre un menú con las siguientes opciones:
# 1 Suma
# 2 Resta
# 3 Multiplicación
# 5 División
# 0 Salir

def pedir_validar_num():
    try:
        num1 = int(input('Introduce un número: '))
        num2 = int(input('Introduce un número: '))
        return num1, num2
    except Exception as e:
        raise ValueError(f'Se deben meter números, no caracteres. {e}')
    
def menu():
    print('1 Suma')
    print('2 Resta')
    print('3 Multiplicación')
    print('4 División')
    print('0 Salir')

def sumar(x, y):
    return x + y

def restar(x, y):
    return x - y

def multiplicar(x, y):
    return x * y

def dividir(x, y):
    return x / y

salir = False

while not salir:
    menu()
    try:
        opcion = int(input('Introduce una opción del menú (número): '))
    except Exception as e:
        print(f'La opción introducida debe de ser un número: {e}')
    match opcion:
        case 1:
            num1, num2 = pedir_validar_num()
            print(f'La suma de {num1} + {num2} = {sumar(num1, num2)}')
        case 2:
            num1, num2 = pedir_validar_num()
            print(f'La resta de {num1} - {num2} = {restar(num1, num2)}')
        case 3:
            num1, num2 = pedir_validar_num()
            print(f'La multiplicación de {num1} * {num2} = {multiplicar(num1, num2)}')
        case 4:
            num1, num2 = pedir_validar_num()
            print(f'La división de {num1} / {num2} = {dividir(num1, num2)}')
        case 0:
            salir = True
            break
        case _:
            print('Introduce una opción correcta.')
# Out:
# 1 Suma
# 2 Resta
# 3 Multiplicación
# 4 División
# 0 Salir
# La suma de 1 + 2 = 3
# 1 Suma
# 2 Resta
# 3 Multiplicación
# 4 División
# 0 Salir
# La resta de 1 - 2 = -1
# 1 Suma
# 2 Resta
# 3 Multiplicación
# 4 División
# 0 Salir
# La multiplicación de 1 * 2 = 2
# 1 Suma
# 2 Resta
# 3 Multiplicación
# 4 División
# 0 Salir
# La división de 1 / 2 = 0.5
# 1 Suma
# 2 Resta
# 3 Multiplicación
# 4 División
# 0 Salir
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 40
#      39 try:
# ---> 40     opcion = int(input('Introduce una opción del menú (número): '))
#      41 except Exception as e:
#
# ValueError: invalid literal for int() with base 10: 'sasd'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 42
# ...

# %%
# Ejercicio 2
CONST_FARENHAIT = 1.8
try:
    celsius = float(input('Introduce la temperatura en Cº Celsius: ')) 
except Exception as e:
    print(f'El valor introducido debe de ser un número')
print(f'La conversión de {celsius} Cº Celsius a Farenhait es: {celsius * CONST_FARENHAIT + 32}')
# Out:
# La conversión de 23.0 Cº Celsius a Farenhait es: 73.4

# %%
# Ejercicio 3. Suponiendo que tu nombre está en una variable llamada nombre, realiza solo una llamada a la función print para obtener los siguientes resultados
# a) Hola, me llamo <nombre>
# b) <nombre> repetido 5 veces separadas por el caracter "*"

nombre = 'Daniel'
print(f'Hola, me llamo {nombre}')
print('*'.join([nombre]*5))
# Out:
# Hola, me llamo Daniel
# Daniel*Daniel*Daniel*Daniel*Daniel

# %%
# Ejercicio 4. Imprimir por pantalla las siguientes cadenas de caracteres:
# a) I'm a student
# b) "I'm a student"
# c) Es difícil escribir 'una cadena con el carácter" '

print('I\'m student')
print('"I\'m student"')
print('Es difícil escribir \'una cadena con el carácter\" \'')
# Out:
# I'm student
# "I'm student"
# Es difícil escribir 'una cadena con el carácter" '

# %%
# Ejercicio 5. Verifica si un número introducido es mayor que 10
texto = ''
try:
    numero_input = int(input('Introduce un número: '))
except Exception as e:
    print(f'Error al introducir el número: {e}')
else:
    if numero_input > 10:
        texto = f'El número {numero_input} es > 10.'
    else:
        texto = f'El número {numero_input} es < o igual que 10.'

    print(texto)
# Out:
# Error al introducir el número: invalid literal for int() with base 10: 'asas'

# %%
# Ejercicio 6. Pide una edad y comprueba si la persona es mayor de edad y no supera 65
try:
    edad = int(input('Introduce una edad: '))
except Exception as e:
    print(f'Error a la hora de introducir una edad: {e}')
else:
    if edad < 18:
        texto = 'La persona no es mayor de edad.'
    elif edad > 65:
        texto = 'La personsa no es mayor de 65 años'
    else:
        texto = 'La persona es mayor de edad pero no supera los 65 años.'
    print(texto)
# Out:
# Error a la hora de introducir una edad: invalid literal for int() with base 10: 'asas'

# %%
# Ejericicio 7 Escribe una expresión que determine si una contraseña es válida cuando:
# • Tiene más de 8 caracteres
# • Contiene la letra "@"
# • No contiene espacios

password = input('Introduce una contraseña que contenga: + de 8 caracteres, contenga \"@\" y no contenga espacios')
if len(password) == 0:
    print('No has introducido ningún valor.')
elif len(password) <= 8 and '@' not in password and ' ' in password:
    print('Recuerda que la contraseña debe de tener + de 8 caractares, un \"@\" y no puede contener espacios')
elif len(password)<=8:
    print('La contraseña debe de tener más de 8 caracteres.')
elif '@' not in password:
    print('La contraseña debe de tener el caracter \"@\"')
elif ' ' in password:
    print('La contraseña no debe de contener ningún espacio.')
else:
    print('La contraseña es correcta')
# Out:
# La contraseña no debe de contener ningún espacio.

# %%
# Ejercicio 8 Dada la cadena "pythonista":
#• Muestra la primera letra
#• Muestra la última
#• Muestra la letra con índice 4

cadena = 'pythonista'
print(cadena[0])
print(cadena[len(cadena) - 1])
print(cadena[4])
# Out:
# p
# a
# o

# %%
# Ejercicio 9. Pide una cadena de caracteres por teclado e imprímela en 2 líneas dividida por la mitad. No se pueden usar bucles. Por ejemplo, la cadena "casa" daría como resultado
#ca
#sa
#Y la cadena "remar" daría
#rem
#ar

cadena = input('Introduce una cadena: ')
if len(cadena) % 2 == 0:
    print(cadena[:len(cadena)//2])
    print(cadena[len(cadena)//2:])
else:
    print(cadena[:len(cadena)//2+1])
    print(cadena[len(cadena)//2+1:])
# Out:
# ca
# sa

# %%
# Ejercicio 10. Toma una frase y crea una nueva cadena donde las letras en índice par estén en minúscula y as de índice impar en mayúscula.
cadena = input('Introduce una cadena: ')
resultado = ''
for i in range(len(cadena)):
    resultado += cadena[i].lower() if i % 2 == 0 else cadena[i].upper()
print(resultado)
# Out:
# HoLa

# %%
# Ejercicio 11. Declara variables de todos los tipos que hemos estudiado y muestra por pantalla para cada una de ellas:
# La variable <nombre de la vble> vale <valor de la vble> y es de tipo <tipo de la vble>
entero = 10
float = 10.55
cadena = 'Daniel'
bool = True
lista = [1,2,3,4,5]

print(f'La variable entero vale {entero} y es de tipo {type(entero)}')
print(f'La variable float vale {float} y es de tipo {type(float)}')
print(f'La variable cadena vale {cadena} y es de tipo {type(cadena)}')
print(f'La variable bool vale {bool} y es de tipo {type(bool)}')
print(f'La variable lista vale {lista} y es de tipo {type(lista)}')
# Out:
# La variable entero vale 10 y es de tipo <class 'int'>
# La variable float vale 10.55 y es de tipo <class 'float'>
# La variable cadena vale Daniel y es de tipo <class 'str'>
# La variable bool vale True y es de tipo <class 'bool'>
# La variable lista vale [1, 2, 3, 4, 5] y es de tipo <class 'list'>

# %%
# Ejercicio 12. Dado un valor en segundos, usa variables para calcular horas, minutos y segundos
try:
    segundos_input = int(input('Introduce los segundo que desees: '))
except Exception as e:
    print('Error a la hora de introducir los segundos.')
else:
    segundos_min = segundos_input / 60
    segundos_horas = segundos_input / 3600
    print(f'{segundos_input} segundos es {segundos_min} minutos\n{segundos_input} segundos es {segundos_horas} horas')
# Out:
# 3600 segundos es 60.0 minutos
# 3600 segundos es 1.0 horas

# %%
# Ejercicio 13. Calcula si un año introducido por teclado es bisiesto (los divisibles por 4 excepto los que también sean divisibles por 100 o por 400)
try:
    anio  = int(input('Introduce por teclado un año y te diremos si es bisiesto o no: '))
    if anio / 4 or anio / 100 or anio / 400:
        print('El año introduciso es bisiesto.')
    else:
        print('El año introducido no es bisiesto.')
except Exception  as e:
    print(f'Error al introducir la variable año: {e}')

# %%
# Ejercicio 14. Dado un número, comprueba si la parte entera es mayor quer la parte decimal
try:
    entrada = float(input('Introduce un número para calcular si la parte entera es mayor que la decimal: '))
    entrada_multiplicada = entrada * 10
    entrada_resto = entrada_multiplicada % 10
    entrada_divisor = entrada_multiplicada // 10
    
    if entrada_divisor > entrada_resto:
        print('La parte entera es mayor que el resto')
    elif entrada_divisor < entrada_resto:
        print('La parte entera es menor que el resto')
    else:
        print('La parte entera es igual que la parte decimal')

except Exception as e:
    print(f'Error al introducir la variable numero: {e}')
# Out:
# La parte entera es igual que la paret decimal

# %%
# Ejercicio 15. Compara tres números y determina cuál es el mayor usando solo operadores relacionales
try:
    numero1 = int(input('Introduce un número: '))
    numero2 = int(input('Introduce un segundo número: '))
    numero3 = int(input('Introduce un tercer número: '))

    if numero1 > numero2 and numero1 > numero3:
        print(f'El número más grande introducido es: {numero1}')
    elif numero2 > numero1 and numero2 > numero3:
        print(f'El número más grande introducido es: {numero2}')
    else:
        print(f'El número más grande introducido es: {numero3}')
except Exception as e:
    print(f'Error al introducir algunos de los números: {e}')
# Out:
# El número más grande introducido es: 3

# %%
# Ejercicio 16. Comprueba si un número es par o múltiplo de 5 usando or
try:
    numero = int(input('Introduce un número y te diremos es par o múltiplo de 5'))
    if numero % 2 == 0 or numero % 5 == 0:
        print('El número introducido es par o múltiplo de 5.')
    else:
        print('El número introducido ni es par ni es múltiplo de 5.')
except Exception as e:
    print(f'Error al introducir el valor de la variable: {e}')

# %%
# Ejercicio 17. Escribe un programa que pregunte si llueve y si tienes paraguas, y determine si puedes salir (usa lógica)
q_is_lloviendo = input('¿Está lloviendo en el lugar en que te encuentras?. Responde Si o No:').lower()

if q_is_lloviendo == 'si':
    q_paraguas = input('¿Tienes paraguas?. Responde Si o No:').lower()
    if q_paraguas == 'si':
      print('Puedes salir, aunque el día este lluvioso, tienes paraguas.')  
    elif q_paraguas == 'no':
        print('No puedes salir, el día esta lluvioso y no tienes paraguas.')
    else:
        print('Introduce como respuesta Si o No')
elif q_is_lloviendo == 'no':
    print('Puedes salir, el día no es lluvioso.')
else:
    print('Introduce como respuesta Si o No')
# Out:
# Introduce como respuesta Si o No

# %%
# Ejercicio 18. Realiza un desplazamiento a la izquierda: calcula 7 << 2 y explica el resultado
print(7 << 2)
print('El resulatdo es: 28')
# Out:
# 28
# El resulatdo es:

# %%
# Ejercicio 19. Realiza un desplazamiento a la derecha: calcula 20 >> 3
print(20 >> 3)
print('El resultado del desplazamiento es: 2')
# Out:
# 2
# El resultado del desplazamiento es: 2

# %%
# Ejercicio 20. Aplica el operador NOT (~) a 0b1010 y muestra el resultado en binario usando una máscara de 4 bits
n = 0b1010
bits = 4
mask = (1 << bits) - 1
inverso = ~n & mask
print(f'{inverso:b}')
# Out:
# 101

# %%
# Ejercicio 21. Escribe un programa que determine si el bit menos significativo de un número es 1 (el menos significativo es el que está más a la derecha)
n = 0b1010
mask = 1
if n & mask == 0: 
    print('El untimo bit del numero es 0')
else:
    print('El untimo bit del numero es 1')
# Out:
# 0
